# %%
import os
import matplotlib.pyplot as plt

# %%
DATA_DIR = "../dataset/raw"

class_counts = {}

for cls in os.listdir(DATA_DIR):
    path = os.path.join(DATA_DIR, cls)
    if os.path.isdir(path):
        class_counts[cls] = len(os.listdir(path))

class_counts
# Out:
# {'Pepper__bell___Bacterial_spot': 997,
#  'Pepper__bell___healthy': 1478,
#  'Potato___Early_blight': 1000,
#  'Potato___healthy': 152,
#  'Potato___Late_blight': 1000,
#  'Tomato_Bacterial_spot': 2127,
#  'Tomato_Early_blight': 1000,
#  'Tomato_healthy': 1591,
#  'Tomato_Late_blight': 1909,
#  'Tomato_Leaf_Mold': 952,
#  'Tomato_Septoria_leaf_spot': 1771,
#  'Tomato_Spider_mites_Two_spotted_spider_mite': 1676,
#  'Tomato__Target_Spot': 1404,
#  'Tomato__Tomato_mosaic_virus': 373,
#  'Tomato__Tomato_YellowLeaf__Curl_Virus': 3208}

# %%
plt.figure(figsize=(10,5))
plt.bar(class_counts.keys(), class_counts.values())
plt.xticks(rotation=90)
plt.ylabel("Number of Images")
plt.title("Class Distribution")
plt.tight_layout()
plt.show()

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\sanjana\anaconda3\lib\site-packages (4.13.0.90)
# Requirement already satisfied: numpy>=2 in c:\users\sanjana\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

cls = list(class_counts.keys())[0]
imgs = os.listdir(f"{DATA_DIR}/{cls}")[:3]

plt.figure(figsize=(6,2))
for i, img in enumerate(imgs):
    im = cv2.imread(f"{DATA_DIR}/{cls}/{img}")
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    plt.subplot(1,3,i+1)
    plt.imshow(im)
    plt.axis("off")

plt.suptitle(f"Sample images from {cls}")
plt.show()
